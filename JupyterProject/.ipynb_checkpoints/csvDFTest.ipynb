# %%
import pandas as pd

# %%
df=pd.read_csv("E:\ebooks\DataScience with Python\cereals.csv")
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name')
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df.head(7)
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094

# %%
df.tail(7)
# Out:
#                         name  calories  protein  vitamins     rating
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %%
df[1:4]
# Out:
#                         name  calories  protein  vitamins     rating
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
thirdRow=[False,False,True,False,False]
df[thirdRow]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2516\3192147841.py in <module>
#       1 thirdRow=[False,False,True,False,False]
# ----> 2 df[thirdRow]
#
# c:\python3.7.4\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# c:\python3.7.4\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3495         elif len(key) != len(self.index):
#    3496             raise ValueError(
# -> 3497                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3498             )
#    3499
#
# ValueError: Item wrong length 5 instead of 10.

# %%
condition=df['calories']>70
df[condition]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df[(df['calories']>70)&(df['protein']<4)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df[(df['calories']>70)|(df['protein']<4)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.loc[0,'name']
# Out:
# '100% Bran'

# %%
df.loc[[0],['name']]
# Out:
#         name
# 0  100% Bran

# %%
df.loc[[5,8],'name':'protein']
# Out:
#                       name  calories  protein
# 5  Apple Cinnamon Cheerios       110        2
# 8                Bran Chex        90        2

# %%
df['My Column']=['A','A','A','A','A','A','A','A','A','A']
df
# Out:
#                         name  calories  protein  vitamins     rating My Column
# 0                  100% Bran        70        4        25  68.402973         A
# 1          100% Natural Bran       120        3         0  33.983679         A
# 2                   All-Bran        70        4        25  59.425505         A
# 3  All-Bran with Extra Fiber        50        4        25  93.704912         A
# 4             Almond Delight       110        2        25  34.384843         A
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541         A
# 6                Apple Jacks       110        2        25  33.174094         A
# 7                    Basic 4       130        3        25  37.038562         A
# 8                  Bran Chex        90        2        25  49.120253         A
# 9                Bran Flakes        90        3        25  53.313813         A

# %%
df.drop('My Column',axis=1,inplace=True)
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.sort_values(by='calories')
# Out:
#                         name  calories  protein  vitamins     rating
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562

# %%
df.sort_values(by='calories',ascending=False)
# Out:
#                         name  calories  protein  vitamins     rating
# 7                    Basic 4       130        3        25  37.038562
# 1          100% Natural Bran       120        3         0  33.983679
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
scoreData={'Gender':['Female','Male','Female','Male'],'Score':[85,88,95,80]}

# %%
dfscore=pd.DataFrame.from_dict(scoreData)
dfscore
# Out:
#    Gender  Score
# 0  Female     85
# 1    Male     88
# 2  Female     95
# 3    Male     80

# %%
dfscore.groupby(by='Gender').mean()
# Out:
#         Score
# Gender
# Female   90.0
# Male     84.0

# %%
import seaborn as sns
x_axis=df.index
y_axis=df['calories']
sns.scatterplot(x=x_axis,y=y_axis,hue=df['name'])
# Out:
# <AxesSubplot:ylabel='calories'>

# %%
x_axis=dfscore.index
y_axis=dfscore['Score']
sns.scatterplot(x=x_axis,y=y_axis,hue=dfscore['Gender'])
# Out:
# <AxesSubplot:ylabel='Score'>

# %%
sns.stripplot(x=dfscore['Gender'],y=dfscore['Score'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Score'>

# %%
sns.displot(df['rating'])

# %%
sns.boxplot(dfscore['Score'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['calories'])
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x=dfscore['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x=df['calories'])
# Out:
# <AxesSubplot:xlabel='calories', ylabel='count'>
